# %%
import warnings
from collections import defaultdict

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

DIR_PATH = "./Datasets"
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = (28, 10)

# %% [markdown]
# ### Data Exploration & Feature Engineering

# %% [markdown]
#   - https://dcc.icgc.org/releases/PCAWG/evolution_and_heterogeneity
#   - https://www.science.org/doi/full/10.1126/science.abl9283 (table S6)
#   - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6872491/ (table S2)
#   - https://www.nature.com/articles/s43018-021-00200-0 (table S9)

# %%
df = pd.read_csv(f"{DIR_PATH}/phg_clincal_activities_and_signatures.csv").set_index("Unnamed: 0")
df.head()
# Out:
#                                          pcawg_class    WGD  num_subclones  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f   Ovary-AdenoCA   True            1.0
# 003819bc-c415-4e76-887c-931d60ed39e7   CNS-PiloAstro  False            1.0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412       Liver-HCC  False            1.0
# 00493087-9d9d-40ca-86d5-936f1b951c93       CNS-Oligo  False            1.0
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  Panc-Endocrine  False            2.0
#
#                                      tumour_type reported_sex  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f   Recurrent       Female
# 003819bc-c415-4e76-887c-931d60ed39e7     Primary       Female
# 0040b1b6-b07a-4b6e-90ef-133523eaf412     Primary         Male
# 00493087-9d9d-40ca-86d5-936f1b951c93     Primary       Female
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa     Primary       Female
#
#                                       donor_survival_time  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f               1972.0
# 003819bc-c415-4e76-887c-931d60ed39e7                244.0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412               1905.0
# 00493087-9d9d-40ca-86d5-936f1b951c93                  NaN
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                  7.0
#
#                                       donor_age_at_diagnosis tumour_stage  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f                    54.0          NaN
# 003819bc-c415-4e76-887c-931d60ed39e7                     4.0          NaN
# 0040b1b6-b07a-4b6e-90ef-133523eaf412                    73.0          NaN
# 00493087-9d9d-40ca-86d5-936f1b951c93                    47.0          NaN
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                    59.0       T2N1MX
#
#                                                        tumour_grade  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f                            NaN
# 003819bc-c415-4e76-887c-931d60ed39e7                              1
# 0040b1b6-b07a-4b6e-90ef-133523eaf412                             G2
# 00493087-9d9d-40ca-86d5-936f1b951c93                            NaN
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  2 - Moderately differentiated
#
#                                      first_therapy_type  ...     SBS85  \
# Unnamed: 0                                               ...
# 0009b464-b376-4fbc-8a56-da538269a02f                NaN  ...  0.004170
# 003819bc-c415-4e76-887c-931d60ed39e7                NaN  ...  0.011223
# 0040b1b6-b07a-4b6e-90ef-133523eaf412       no treatment  ...  0.010256
# 00493087-9d9d-40ca-86d5-936f1b951c93                NaN  ...  0.034194
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                NaN  ...  0.002131
#
#                                          SBS86     SBS87     SBS88     SBS89  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f  0.032632  0.009180  0.004538  0.015247
# 003819bc-c415-4e76-887c-931d60ed39e7  0.000018  0.043297  0.002587  0.000110
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.001064  0.000472  0.006128  0.014017
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.007644  0.066593  0.003875  0.008409
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.006881  0.014572  0.005315  0.034945
#
#                                          SBS90     SBS91     SBS92     SBS93  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f  0.023516  0.001096  0.001524  0.041314
# 003819bc-c415-4e76-887c-931d60ed39e7  0.001679  0.000330  0.008414  0.012260
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.003671  0.002160  0.015290  0.010472
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.001092  0.004163  0.013443  0.012461
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.000375  0.024285  0.001300  0.002455
#
#                                          SBS94
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f  0.074747
# 003819bc-c415-4e76-887c-931d60ed39e7  0.010864
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.012708
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.046001
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.023321
#
# [5 rows x 119 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18947 entries, 0009b464-b376-4fbc-8a56-da538269a02f to CPCT02220071T
# Columns: 119 entries, pcawg_class to SBS94
# dtypes: float64(85), int64(1), object(33)
# memory usage: 17.3+ MB

# %%
SBS_COLS = [col for col in df.columns if "SBS" in col]
DATA_COLS = [col for col in df.columns if "SBS" not in col]
OBJECT_COLS = df.select_dtypes(include=['object']).columns
TARGET = "tumour_type"
DATA_COLS
# Out:
# ['pcawg_class',
#  'WGD',
#  'num_subclones',
#  'tumour_type',
#  'reported_sex',
#  'donor_survival_time',
#  'donor_age_at_diagnosis',
#  'tumour_stage',
#  'tumour_grade',
#  'first_therapy_type',
#  'first_therapy_response',
#  'specimen_donor_treatment_type',
#  'smoking_history',
#  'tobacco_smoking_intensity',
#  'alcohol_history',
#  'alcohol_history_intensity',
#  'ancestry_primary',
#  'ancestry_primary_contribution',
#  'cohort',
#  'organ',
#  'is_pretreated',
#  'had_radiotherapy',
#  'is_hypermutated',
#  'HRD',
#  'biopsy_site',
#  'had_other_treatment',
#  'had_chemotherapy',
#  'had_hormone_therapy',
#  'had_targeted_therapy',
#  'had_immunotherapy',
#  'treatment_platinum',
#  'treatment_5FU',
#  'genetic_immune_escape',
#  'primary_tumour_location',
#  'cancer_subtype',
#  'age_at_biopsy',
#  'MSIseq',
#  'MMRDetect',
#  'qc_pass',
#  'stage_coarse',
#  'TMB']

# %%
df[DATA_COLS].describe().T
# Out:
#                                  count          mean           std        min  \
# num_subclones                   2778.0      1.030238      0.730887   0.000000
# donor_survival_time             1754.0   1223.050741   1333.317455   0.000000
# donor_age_at_diagnosis          2650.0     56.165660     19.249394   1.000000
# tobacco_smoking_intensity        150.0     27.566667     26.616949   0.000000
# ancestry_primary_contribution   2569.0      0.958425      0.086477   0.340681
# age_at_biopsy                   2004.0     61.261477     11.329076  19.000000
# stage_coarse                     530.0      2.509434      0.970698   1.000000
# TMB                            18947.0  23365.237663  93283.930542  21.000000
#
#                                        25%          50%         75%  \
# num_subclones                     1.000000     1.000000      1.0000
# donor_survival_time             413.000000   810.000000   1460.7500
# donor_age_at_diagnosis           48.000000    60.000000     70.0000
# tobacco_smoking_intensity         0.000000    21.000000     50.0000
# ancestry_primary_contribution     0.961663     0.994459      0.9996
# age_at_biopsy                    54.000000    63.000000     69.0000
# stage_coarse                      2.000000     3.000000      3.0000
# TMB                            3460.000000  6878.000000  15297.0000
#
#                                         max
# num_subclones                  4.000000e+00
# donor_survival_time            1.095800e+04
# donor_age_at_diagnosis         9.000000e+01
# tobacco_smoking_intensity      8.600000e+01
# ancestry_primary_contribution  9.996000e-01
# age_at_biopsy                  8.900000e+01
# stage_coarse                   4.000000e+00
# TMB                            2.745037e+06

# %%
df[DATA_COLS].isna().sum(axis = 0)
# Out:
# pcawg_class                      16169
# WGD                              14149
# num_subclones                    16169
# tumour_type                      12752
# reported_sex                     14149
# donor_survival_time              17193
# donor_age_at_diagnosis           16297
# tumour_stage                     17456
# tumour_grade                     17475
# first_therapy_type               17962
# first_therapy_response           18393
# specimen_donor_treatment_type    17179
# smoking_history                  17640
# tobacco_smoking_intensity        18797
# alcohol_history                  17730
# alcohol_history_intensity        17730
# ancestry_primary                 16378
# ancestry_primary_contribution    16378
# cohort                               0
# organ                                0
# is_pretreated                    16927
# had_radiotherapy                 17038
# is_hypermutated                  16934
# HRD                              16927
# biopsy_site                      16935
# had_other_treatment              17764
# had_chemotherapy                 17764
# had_hormone_therapy              17764
# had_targeted_therapy             17764
# had_immunotherapy                17764
# treatment_platinum               17444
# treatment_5FU                    17444
# genetic_immune_escape            17045
# primary_tumour_location          16927
# cancer_subtype                   17799
# age_at_biopsy                    16943
# MSIseq                           16927
# MMRDetect                        16927
# qc_pass                          16169
# stage_coarse                     18417
# TMB                                  0
# dtype: int64

# %% [markdown]
# Quite large numbers of NaN's. Discarding those is a bad decision, a lot of data will be lost

# %%
for col in DATA_COLS:
    print(f"Column - {col}")
    print(f"Unique values - {df[col].unique()}")
    print(f"NaN percentage - {df[col].isna().sum() / df[col].shape[0]}")
    print()
# Out:
# Column - pcawg_class
# Unique values - ['Ovary-AdenoCA' 'CNS-PiloAstro' 'Liver-HCC' 'CNS-Oligo' 'Panc-Endocrine'
#  'Kidney-RCC' 'Prost-AdenoCA' 'Thy-AdenoCA' 'ColoRect-AdenoCA'
#  'Lymph-BNHL' 'Uterus-AdenoCA' 'Breast-AdenoCA' 'Lung-AdenoCA'
#  'Panc-AdenoCA' 'Eso-AdenoCA' 'Head-SCC' 'CNS-Medullo' 'CNS-GBM'
#  'Bone-Leiomyo' 'Cervix-SCC' 'Skin-Melanoma' 'Lymph-CLL' 'Kidney-ChRCC'
#  'Stomach-AdenoCA' 'Lung-SCC' 'Bladder-TCC' 'Lymph-NOS' 'Myeloid-AML'
#  'Biliary-AdenoCA' 'Breast-LobularCA' 'Cervix-AdenoCA' 'Bone-Osteosarc'
#  'Breast-DCIS' 'Myeloid-MPN' 'Myeloid-MDS' 'Bone-Cart' 'Bone-Epith' nan]
# NaN percentage - 0.8533804823982688
#
# Column - WGD
# Unique values - [True False nan]
# NaN percentage - 0.7467672982530216
#
# Column - num_subclones
# Unique values - [ 1.  2.  0.  3.  4. nan]
# NaN percentage - 0.8533804823982688
#
# Column - tumour_type
# Unique values - ['Recurrent' 'Primary' 'Metastatic' 'Cell' nan]
# NaN percentage - 0.6730353090198976
#
# Column - reported_sex
# Unique values - ['Female' 'Male' nan]
# NaN percentage - 0.7467672982530216
#
# Column - donor_survival_time
# Unique values - [1972.  244. 1905. ...   19. 1455.  837.]
# NaN percentage - 0.9074259777273447
#
# Column - donor_age_at_diagnosis
# Unique values - [54.  4. 73. 47. 59. 62. 50. 44. 70. 68. 31. 10. 49. 78. 57. 77. 76. 46.
#  52. 64. 66.  9.  7. 15. 38. 75. 53. 56. 14. nan 21. 61. 82. 30. 45.  8.
#  60. 26. 71. 58. 80.  5.  6. 11. 74. 72. 43. 55. 67. 79. 69. 63. 65. 51.
#  22. 42.  1. 39. 48. 23. 84. 27. 41. 86.  2.  3. 85. 81. 34. 37. 83. 32.
#  90. 17. 12. 35. 40. 87. 36. 20. 18. 16. 19. 13. 29. 25. 88. 33. 89. 28.]
# NaN percentage - 0.8601361693144033
#
# Column - tumour_stage
# Unique values - [nan 'T2N1MX' 'T2cN0' 'T1c' 'T2a' 'unknown' '2' 'T1bN0M1' 'T2N0Mx' 'III'
#  '3b' 'IIB' 'T2N0MX' '3' 'M3' 'T1N1bMX' 'B' 'M1' 'T1aNXMX' 'T3N1bMX'
#  'T1N1M1' 'T3bN1' 'T1N0M0' 'A' 'T4N1M1' 'T3a' 'T3N1M0' 'T2c' '2b' 'IIA'
#  '1' 'IB' 'T2N1M1' 'T3N0MX' 'M0' 'T3N0M0' 'T3N1Mx' '1a' '3c' 'pT4aN2bM0'
#  'T1N0MX' '4' 'T3aN0' 'IV' 'T3N1MX' 'C' 'T3aN0M0' 'T3aNXMX' 'T2N1aMx'
#  'T2b' 'T2N3M0' 'T4N3M0' 'T3b' 'T4N1M0' 'T2N1bMX' 'IIIA' 'T4N0M0'
#  'pT4aN0M0' '2a' 'T2N1M0' 'T2N0M0' 'I' '1b' 'T3N1M1' 'T3N3M0' 'T1bN0MX'
#  '3a' 'T2N2M0' 'pT4aN1M0' 'T3aNX' 'T1aN0M0' 'T3aN0MX' 'T3bN0' 'pT2N0M0'
#  'T2bNXMX' 'T1N0' 'M2' 'T4N1bM1' 'T3N2M0' 'T4NXMX' 'T1bNXMX' 'T4N1'
#  'T3N0Mx' 'IIIB' 'T1N0Mx' 'T3N1M2' 'IA' 'T2aN0' 'T2aN1MX' 'T2cNX' 'IVA'
#  'T1bN0M0' 'T4N2M1' 'T3NXMX' 'T4N2M0' 'TxNxMx' 'pT2N2bM0' 'TXNXM1'
#  'T2NxMx' 'T3N0M1' 'T3N1aMX' 'T2aNXMX' 'T3N0' 'T4aN2' 'T3bNXMX' 'IIIC'
#  'T2N0M1' 'II' 'T3aN1MX' 'T2cN1' 'T3cN0M0' 'T2NxM0' 'T1N1M0' 'T3aN0Mx'
#  'T2cN0Mx' 'T3bN0Mx' 'T3bN1M0' 'T3bNxMx' 'T3aNxMx' 'T2cNxMx' 'T2N1Mx'
#  'T1N1Mx' 'T2N2M2' 'T1N3M0']
# NaN percentage - 0.9213068031878398
#
# Column - tumour_grade
# Unique values - [nan '1' 'G2' '2 - Moderately differentiated' '3+4' '4+3' 'unknown'
#  'II-III' '2' '1 - Well differentiated' 'II-I' '3' 'FL grade I'
#  'Well differentiated' 'G4' 'FL grade II' '3 - Poorly differentiated'
#  'DLBCL grade cb' 'II' 'NET-G3' 'III' '3+3' 'NET-G1'
#  'X - Cannot be assessed' '4' 'Moderately differentiated' 'G3' 'I'
#  '4 - Undifferentiated' 'WD' 'NET-G2' 'G1' 'I-II' 'Poorly differentiated'
#  'IV' 'FL grade IIIa' 'FL grade IIIb' '5+4' 'Undifferentiated'
#  'Status Post Therapy' 'PD' 'DLBCL grade ib' 'needs cpath clarification'
#  'Moderate to Poor' 'I-III' '3+5' '4+4']
# NaN percentage - 0.9223096004644534
#
# Column - first_therapy_type
# Unique values - [nan 'no treatment' 'other therapy' 'combined chemo+radiation therapy'
#  'radiation therapy' 'surgery' 'chemotherapy'
#  'monoclonal antibodies (for liquid tumours)']
# NaN percentage - 0.9480128780281839
#
# Column - first_therapy_response
# Unique values - [nan 'partial response' 'complete response' 'stable disease' 'unknown'
#  'disease progression']
# NaN percentage - 0.9707605425661054
#
# Column - specimen_donor_treatment_type
# Unique values - ['other therapy' 'no treatment' nan 'surgery' 'chemotherapy'
#  'combined chemo+radiation therapy']
# NaN percentage - 0.9066870744708925
#
# Column - smoking_history
# Unique values - [nan 'Smoking history not documented'
#  'Lifelong non-smoker (<100 cigarettes smoked in lifetime)'
#  'Current reformed smoker, duration not specified'
#  'Current reformed smoker for > 15 years'
#  'Current smoker (includes daily smokers non-daily/occasional smokers)'
#  'Current reformed smoker for <= 15 years' 'Former' 'Never' 'Current']
# NaN percentage - 0.9310181031297831
#
# Column - tobacco_smoking_intensity
# Unique values - [nan 25. 60. 20.  0. 86. 29. 35. 42. 24. 18. 38. 15. 26. 13.  1. 40. 54.
#  19.  5. 62. 50. 12. 14.  2.  6. 41. 10. 30. 16.  3. 28. 45.  8. 56. 39.
#  53. 48. 75. 57. 58. 22. 36. 78. 51. 37.]
# NaN percentage - 0.9920831793951549
#
# Column - alcohol_history
# Unique values - [nan "Don't know/Not sure" 'no' 'yes']
# NaN percentage - 0.9357681954926901
#
# Column - alcohol_history_intensity
# Unique values - [nan 'Not Documented' 'None' 'Weekly Drinker (>=1x a week)'
#  'Social Drinker (> once a month, < once a week)'
#  'Occassional Drinker (< once a month)' 'Daily Drinker']
# NaN percentage - 0.9357681954926901
#
# Column - ancestry_primary
# Unique values - ['EUR' 'ASN' 'AFR' nan 'AMR' 'SAN']
# NaN percentage - 0.8644112524410197
#
# Column - ancestry_primary_contribution
# Unique values - [0.9983788 0.9316405 0.9996    ... 0.978043  0.9353885 0.9961683]
# NaN percentage - 0.8644112524410197
#
# Column - cohort
# Unique values - ['PCAWG' 'GEL' 'ICGC' 'HMF']
# NaN percentage - 0.0
#
# Column - organ
# Unique values - ['Ovary' 'CNS' 'Liver' 'Pancreas' 'Kidney' 'Prostate' 'Thyroid'
#  'Colorectal' 'Lymphoid' 'Uterus' 'Breast' 'Lung' 'Esophagus' 'Head_Neck'
#  'Bone_SoftTissue' 'Cervix' 'Skin' 'Stomach' 'Bladder' 'Biliary' 'NET'
#  'Oral_Oropharyngeal']
# NaN percentage - 0.0
#
# Column - is_pretreated
# Unique values - [nan False True]
# NaN percentage - 0.8933868158547528
#
# Column - had_radiotherapy
# Unique values - [nan False True]
# NaN percentage - 0.8992452631023381
#
# Column - is_hypermutated
# Unique values - [nan False True]
# NaN percentage - 0.8937562674829789
#
# Column - HRD
# Unique values - [nan 'HR_proficient' 'HR_deficient' 'cannot_be_determined']
# NaN percentage - 0.8933868158547528
#
# Column - biopsy_site
# Unique values - [nan 'Liver' 'gall bladder' 'Abdominal wall' 'Lymph node' 'Peritoneum'
#  'abdominal wall' 'liver' 'intra costal' 'Primary' 'other' 'Rectum' 'lung'
#  'cutaneous' 'Amputated upper leg (Leg amputation 16/06/2016)' 'Lung'
#  'Soft tissue' 'skin' 'soft tissue' 'Left scapula' 'Bone'
#  'mass ventrale bladder' 'Salivary gland' 'abdomen' 'subcutaneous' 'Adnex'
#  'Muscle' 'Laesie level costa 9' 'Occiput' 'Abdomen' 'chest wall'
#  'Abdomen/Abdominal wall' 'stomach' 'Thorax wall' 'abdominal mass'
#  'omentum' 'Psoas left' 'Small pelvic' 'Chest wall' 'shoulder' 'pancreas'
#  'leasion' 'Adrenal gland' 'Fibrosarcoma' 'Cutaneous lesions' 'Subcutis'
#  'Omentum' 'Skin' 'subcutis' 'axilla' 'parasternaal' 'Ascites'
#  'mass axillary' 'omentum cake' 'Neck gland' 'Musculus Pectoralis Major'
#  'breast' 'bone' 'mediastinale mass' 'unknown' 'Mamma' 'subcutane'
#  'hypo-echogenic mass chest wall' 'soft tissue mass near sternum'
#  'Omental cake' 'left mamma' 'axillair' 'Muscle back' 'Cutane lesion'
#  'cutis' 'Abdominal mass' 'thorax wall' 'Mass head' 'Skin/Subcutaneous'
#  'Abdominal wall cutaneous' 'Brain' 'Parasternal' 'thorax'
#  'right shoulder' 'adnex' 'iliac' 'breast left' 'Breast' 'lymph node'
#  'vertebral column' 'mass Brain' 'CNS' 'muscle tissue' 'brain'
#  'Glioblastoma' 'brain left temporal GBM' 'ovarium' 'peritoneale'
#  'thoracic wall' 'rectum' 'Intra abdominal mass' 'ilium' 'mesenterium'
#  'vagina' 'Unknown' 'subcutane laesion' 'neck right' 'right side'
#  'Abdominal metastatic' 'upper abdomen' 'sternum' 'cutane'
#  'ABDOMINAL WALL' 'colon' 'Woundbed necrotic cavity perineal'
#  'Thoracic wall' 'skin abdomen' 'muscle' 'abdominal' 'Gall bladder'
#  'esophagus - small intestine' 'gastric mucosa' 'oesophagus'
#  'Cutane metastasis abdomen' 'esophagus' 'abdomen left side' 'Mandible'
#  'Mouth' 'neck right side' 'skinlesion' 'lacrimal sac'
#  'just above a. subclavia left side' 'Endonasal' 'Subcutaneous' 'sinus'
#  'left mandibula' 'Neck lesion' 'Para-vertebral mass' 'Kidney'
#  'adrenal gland' 'Sternum' 'Muscle dorsum' 'Thorax' 'Soft tissue mass'
#  'retro-peritoneal' 'soft tissue mass sacrum' 'duodenum' 'rib'
#  'Abdomen muscle' 'paravertebrale massa' 'pelvis' 'pleural lesion' 'mamma'
#  'pleural' 'trachea' 'swelling back' 'skin leasion' 'bronchus'
#  'Epigastrium' 'shoulder blade' 'Pleura' 'skin/subcutaneous' 'Subcutus'
#  'Para iliacal mass' 'peritoneum' 'ventral abdomen' 'Vagina'
#  'peritonial lesion' 'right axilla' 'Central in abdomen' 'Nates'
#  'subcutane left abdominal' 'right paracolisch right paracolisch'
#  'Vaginal' 'Skin/ subcutaneous' 'm. rectus abdominus'
#  'left retroperitoneal lesion' 'infraclaviculare' 'ovary' 'mass anterieur'
#  'abdominal sampling/debulking'
#  'subcutane, right side just above the umbilicus' 'Oesophagus'
#  'major duodenal papilla' 'Ovarium' 'para-aortal abdominal' 'Bladder'
#  'Urinary tract' 'psoas' 'intraperitoneal mass' 'presternal' 'neck'
#  'Parevertebral' 'Neck' 'Below left nipple' 'gland in the neck'
#  'Cutaneous' 'Ulcus neck' 'subcatenous' 'left axilla'
#  'Left maximus gluteus' 'Mestastasis' 'subcutaneous mass' 'Subcutane'
#  'Subcutane metastasis.' 'Leg' 'upperarm' 'Skin/subcutaneous' 'Scapula'
#  'lesion subcutaneous' 'Back' 'inguinal' 'paravertebral'
#  'skin, medial left upper leg' 'SKIN' 'mass inguinal' 'Soft mass'
#  'Clavicula' 'Stomach' 'neck lymph node' 'esophagus/stomach'
#  'retroperitoneum' 'Abdomen right' 'sarcoma' 'Vulva' 'retroperitoneal'
#  'Abdominal' 'cervix' 'caudaal below liver' 'Thoracal wall']
# NaN percentage - 0.8938090462870112
#
# Column - had_other_treatment
# Unique values - [nan True False]
# NaN percentage - 0.9375626748297884
#
# Column - had_chemotherapy
# Unique values - [nan True False]
# NaN percentage - 0.9375626748297884
#
# Column - had_hormone_therapy
# Unique values - [nan False True]
# NaN percentage - 0.9375626748297884
#
# Column - had_targeted_therapy
# Unique values - [nan False True]
# NaN percentage - 0.9375626748297884
#
# Column - had_immunotherapy
# Unique values - [nan False True]
# NaN percentage - 0.9375626748297884
#
# Column - treatment_platinum
# Unique values - [nan True False]
# NaN percentage - 0.9206734575394522
#
# Column - treatment_5FU
# Unique values - [nan False True]
# NaN percentage - 0.9206734575394522
#
# Column - genetic_immune_escape
# Unique values - [nan True False]
# NaN percentage - 0.8996147147305642
#
# Column - primary_tumour_location
# Unique values - [nan 'Biliary' 'CUP' 'Bone/Soft tissue' 'Uterus' 'Ovary' 'Skin' 'Breast'
#  'CNS' 'Head and neck' 'Choroid' 'Colon/Rectum' 'Other' 'Esophagus'
#  'Kidney' 'Liver' 'Lymphoid' 'Lung' 'Prostate' 'Pancreas' 'NET' 'Stomach'
#  'Urinary tract']
# NaN percentage - 0.8933868158547528
#
# Column - cancer_subtype
# Unique values - [nan 'Gall bladder' 'Cholangiocarcinoma' 'Cholangocarcinoma'
#  'Ampulla of Vater' 'cholangiocarcinoma'
#  'Gastrointestinal stromal tumor (GIST)' 'Leiomyosarcoma' 'Sarcoma'
#  'Ewing sarcoma' 'Angiosarcoma' 'Rhabdomyosarcoma' 'Desmoid'
#  'Osteosarcoma' 'Carcinosarcoma' 'Liposarcoma'
#  'Inflammary myofibroblastic tumor' 'Endometrial' 'Melanoma'
#  'Chondrosarcoma' 'ER-positive/HER2-negative' 'Subtype unknown'
#  'ER-negative/HER2-positive' 'Triple negative' 'ER-positive/HER2-positive'
#  'ER-positive/HER2 unknown' 'triple negative' 'Glioblastoma Multiforme'
#  'Neuroblastoma' 'Astrocytoma' 'Oligodendroglioma' 'Glioma' 'Meningeoma'
#  'Anal' 'Suspcious but diagnosed as Colon/Rectum' 'Ascending' 'Appendix'
#  'Sigmoid' 'Adenocarcinoma' 'Esophagus-Gastric junction'
#  'Lip and Oral Cavity' 'Salivary Gland'
#  'Nasal cavity and paranasal sinuses' 'Oropharyngeal'
#  'Adenoid Cystic Carcinoma' 'Laryngeal' 'Hypopharyngeal' 'Tongue'
#  'Nasopharyngal cancer' 'Renal Cell' 'Hepatocellular' 'Hodgkin'
#  'hepatocellular' 'Non-Small Cell' 'Small Cell' 'Bronchus'
#  'non-Small Cell' 'Extra ovarial serous carcinoma' 'Tuba'
#  'Basal cell carcinoma' 'Retina Melanoma' 'Skin squamous cell carcinoma'
#  'Atypical fibroxanthoma' 'Sweat glands'
#  'Suspicious but diagnosed as Breast' 'Mucoscal Melanoma' 'melanoma'
#  'basal cell carcinoma' 'Merkel cell carcinoma' 'Cardiacarcinoma'
#  'Cervical' 'Other' 'endometrial']
# NaN percentage - 0.9394099329709189
#
# Column - age_at_biopsy
# Unique values - [nan 70. 65. 64. 49. 43. 71. 51. 81. 79. 53. 68. 55. 66. 56. 74. 77. 36.
#  63. 61. 46. 72. 59. 41. 62. 52. 69. 76. 39. 40. 20. 57. 42. 58. 54. 47.
#  23. 60. 45. 19. 67. 21. 44. 50. 75. 30. 48. 25. 78. 85. 37. 32. 26. 38.
#  73. 80. 28. 33. 82. 86. 35. 34. 31. 83. 87. 88. 84. 24. 29. 89.]
# NaN percentage - 0.8942312767192695
#
# Column - MSIseq
# Unique values - [nan 'non-MMRd' 'MMRd']
# NaN percentage - 0.8933868158547528
#
# Column - MMRDetect
# Unique values - [nan 'non-MMRd' 'MMRd']
# NaN percentage - 0.8933868158547528
#
# Column - qc_pass
# Unique values - [True False nan]
# NaN percentage - 0.8533804823982688
#
# Column - stage_coarse
# Unique values - [nan  3.  2.  1.  4.]
# NaN percentage - 0.9720272338628807
#
# Column - TMB
# Unique values - [15727   104 15029 ... 10799  9270 18083]
# NaN percentage - 0.0

# %% [markdown]
# Create column which indicates number of NaN's

# %%
df["Number of NaN's"] = df.isna().sum(axis = 1)
df.head()
# Out:
#                                          pcawg_class    WGD  num_subclones  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f   Ovary-AdenoCA   True            1.0
# 003819bc-c415-4e76-887c-931d60ed39e7   CNS-PiloAstro  False            1.0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412       Liver-HCC  False            1.0
# 00493087-9d9d-40ca-86d5-936f1b951c93       CNS-Oligo  False            1.0
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  Panc-Endocrine  False            2.0
#
#                                      tumour_type reported_sex  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f   Recurrent       Female
# 003819bc-c415-4e76-887c-931d60ed39e7     Primary       Female
# 0040b1b6-b07a-4b6e-90ef-133523eaf412     Primary         Male
# 00493087-9d9d-40ca-86d5-936f1b951c93     Primary       Female
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa     Primary       Female
#
#                                       donor_survival_time  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f               1972.0
# 003819bc-c415-4e76-887c-931d60ed39e7                244.0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412               1905.0
# 00493087-9d9d-40ca-86d5-936f1b951c93                  NaN
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                  7.0
#
#                                       donor_age_at_diagnosis tumour_stage  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f                    54.0          NaN
# 003819bc-c415-4e76-887c-931d60ed39e7                     4.0          NaN
# 0040b1b6-b07a-4b6e-90ef-133523eaf412                    73.0          NaN
# 00493087-9d9d-40ca-86d5-936f1b951c93                    47.0          NaN
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                    59.0       T2N1MX
#
#                                                        tumour_grade  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f                            NaN
# 003819bc-c415-4e76-887c-931d60ed39e7                              1
# 0040b1b6-b07a-4b6e-90ef-133523eaf412                             G2
# 00493087-9d9d-40ca-86d5-936f1b951c93                            NaN
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  2 - Moderately differentiated
#
#                                      first_therapy_type  ...     SBS86  \
# Unnamed: 0                                               ...
# 0009b464-b376-4fbc-8a56-da538269a02f                NaN  ...  0.032632
# 003819bc-c415-4e76-887c-931d60ed39e7                NaN  ...  0.000018
# 0040b1b6-b07a-4b6e-90ef-133523eaf412       no treatment  ...  0.001064
# 00493087-9d9d-40ca-86d5-936f1b951c93                NaN  ...  0.007644
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                NaN  ...  0.006881
#
#                                          SBS87     SBS88     SBS89     SBS90  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f  0.009180  0.004538  0.015247  0.023516
# 003819bc-c415-4e76-887c-931d60ed39e7  0.043297  0.002587  0.000110  0.001679
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.000472  0.006128  0.014017  0.003671
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.066593  0.003875  0.008409  0.001092
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.014572  0.005315  0.034945  0.000375
#
#                                          SBS91     SBS92     SBS93     SBS94  \
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f  0.001096  0.001524  0.041314  0.074747
# 003819bc-c415-4e76-887c-931d60ed39e7  0.000330  0.008414  0.012260  0.010864
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.002160  0.015290  0.010472  0.012708
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.004163  0.013443  0.012461  0.046001
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.024285  0.001300  0.002455  0.023321
#
#                                      Number of NaN's
# Unnamed: 0
# 0009b464-b376-4fbc-8a56-da538269a02f              27
# 003819bc-c415-4e76-887c-931d60ed39e7              23
# 0040b1b6-b07a-4b6e-90ef-133523eaf412              23
# 00493087-9d9d-40ca-86d5-936f1b951c93              29
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa              25
#
# [5 rows x 120 columns]

# %% [markdown]
# Fill NaN's
#
# For objects - set to `"No value"`, for numeric - `.median()`

# %%
for col in DATA_COLS:
    if col in OBJECT_COLS:
        df[col] = df[col].fillna("No value")
    else:
        df[col] = df[col].fillna(df[col].median())

df.isna().sum()
# Out:
# pcawg_class        0
# WGD                0
# num_subclones      0
# tumour_type        0
# reported_sex       0
#                   ..
# SBS91              0
# SBS92              0
# SBS93              0
# SBS94              0
# Number of NaN's    0
# Length: 120, dtype: int64

# %% [markdown]
# Filter dataframe by target

# %%
df = df[df[TARGET].isin(['Primary', 'Metastatic'])]
df.head()
# Out:
#                                          pcawg_class    WGD  num_subclones  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7   CNS-PiloAstro  False            1.0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412       Liver-HCC  False            1.0
# 00493087-9d9d-40ca-86d5-936f1b951c93       CNS-Oligo  False            1.0
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  Panc-Endocrine  False            2.0
# 005794f1-5a87-45b5-9811-83ddf6924568      Kidney-RCC  False            1.0
#
#                                      tumour_type reported_sex  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7     Primary       Female
# 0040b1b6-b07a-4b6e-90ef-133523eaf412     Primary         Male
# 00493087-9d9d-40ca-86d5-936f1b951c93     Primary       Female
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa     Primary       Female
# 005794f1-5a87-45b5-9811-83ddf6924568     Primary       Female
#
#                                       donor_survival_time  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7                244.0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412               1905.0
# 00493087-9d9d-40ca-86d5-936f1b951c93                810.0
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                  7.0
# 005794f1-5a87-45b5-9811-83ddf6924568               2112.0
#
#                                       donor_age_at_diagnosis tumour_stage  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7                     4.0     No value
# 0040b1b6-b07a-4b6e-90ef-133523eaf412                    73.0     No value
# 00493087-9d9d-40ca-86d5-936f1b951c93                    47.0     No value
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                    59.0       T2N1MX
# 005794f1-5a87-45b5-9811-83ddf6924568                    62.0     No value
#
#                                                        tumour_grade  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7                              1
# 0040b1b6-b07a-4b6e-90ef-133523eaf412                             G2
# 00493087-9d9d-40ca-86d5-936f1b951c93                       No value
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  2 - Moderately differentiated
# 005794f1-5a87-45b5-9811-83ddf6924568                              1
#
#                                      first_therapy_type  ...     SBS86  \
# Unnamed: 0                                               ...
# 003819bc-c415-4e76-887c-931d60ed39e7           No value  ...  0.000018
# 0040b1b6-b07a-4b6e-90ef-133523eaf412       no treatment  ...  0.001064
# 00493087-9d9d-40ca-86d5-936f1b951c93           No value  ...  0.007644
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa           No value  ...  0.006881
# 005794f1-5a87-45b5-9811-83ddf6924568           No value  ...  0.002754
#
#                                          SBS87     SBS88     SBS89     SBS90  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7  0.043297  0.002587  0.000110  0.001679
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.000472  0.006128  0.014017  0.003671
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.066593  0.003875  0.008409  0.001092
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.014572  0.005315  0.034945  0.000375
# 005794f1-5a87-45b5-9811-83ddf6924568  0.006760  0.008834  0.040637  0.002801
#
#                                          SBS91     SBS92     SBS93     SBS94  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7  0.000330  0.008414  0.012260  0.010864
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.002160  0.015290  0.010472  0.012708
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.004163  0.013443  0.012461  0.046001
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.024285  0.001300  0.002455  0.023321
# 005794f1-5a87-45b5-9811-83ddf6924568  0.003005  0.011455  0.008315  0.079724
#
#                                      Number of NaN's
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7              23
# 0040b1b6-b07a-4b6e-90ef-133523eaf412              23
# 00493087-9d9d-40ca-86d5-936f1b951c93              29
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa              25
# 005794f1-5a87-45b5-9811-83ddf6924568              26
#
# [5 rows x 120 columns]

# %% [markdown]
# Percentages for each tumour type

# %%
df[TARGET].value_counts() / df.shape[0]
# Out:
# Metastatic    0.577479
# Primary       0.422521
# Name: tumour_type, dtype: float64

# %%
plt.rcParams["figure.figsize"] = (30, 30)
sns.pairplot(data = df[DATA_COLS], hue=TARGET, markers=["o", "s"])

# %%
plt.rcParams["figure.figsize"] = (15, 15)
for col in DATA_COLS:
    if col in OBJECT_COLS:
        sns.countplot(data=df, x=col, hue=TARGET)
    else:
        sns.histplot(data=df, x=col, hue=TARGET)
    plt.show()

# %% [markdown]
# After substituting NaN's, there are clear relationships found in the dataframe between target and other categorical variables.
# Numerical columns also show significant difference between the classes

# %% [markdown]
# Now let's look at signatures columns:

# %%
plt.rcParams["figure.figsize"] = (15, 15)
for col in SBS_COLS:
    sns.histplot(data=df, x=col, hue=TARGET)
    plt.show()

# %% [markdown]
# Hard to make a clear distinguish between two classes - `Primary` is more right skewed for some mutations and vice versa, but overall they are very similar

# %% [markdown]
# Columns that need to be encoded(dummies) and LabelEncoding

# %%
dummies_to_encode = [col for col in (list(OBJECT_COLS) + ["num_subclones", "stage_coarse"]) if col != TARGET]
label_to_encode = list(OBJECT_COLS)
df_dummies = pd.get_dummies(df, columns = dummies_to_encode)
df_dummies.shape
# Out:
# (6163, 746)

# %%
df_label = df.copy(deep = True)
encoders_dict = defaultdict(LabelEncoder)

for col in label_to_encode:
    df_label[col] = df[col].apply(str)
    df_label[col] = encoders_dict[col].fit_transform(df_label[col])

df_label.head()
# Out:
#                                       pcawg_class  WGD  num_subclones  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7           12    0            1.0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412           20    0            1.0
# 00493087-9d9d-40ca-86d5-936f1b951c93           11    0            1.0
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa           32    0            2.0
# 005794f1-5a87-45b5-9811-83ddf6924568           19    0            1.0
#
#                                       tumour_type  reported_sex  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7            1             0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412            1             1
# 00493087-9d9d-40ca-86d5-936f1b951c93            1             0
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa            1             0
# 005794f1-5a87-45b5-9811-83ddf6924568            1             0
#
#                                       donor_survival_time  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7                244.0
# 0040b1b6-b07a-4b6e-90ef-133523eaf412               1905.0
# 00493087-9d9d-40ca-86d5-936f1b951c93                810.0
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                  7.0
# 005794f1-5a87-45b5-9811-83ddf6924568               2112.0
#
#                                       donor_age_at_diagnosis  tumour_stage  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7                     4.0            29
# 0040b1b6-b07a-4b6e-90ef-133523eaf412                    73.0            29
# 00493087-9d9d-40ca-86d5-936f1b951c93                    47.0            29
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa                    59.0            52
# 005794f1-5a87-45b5-9811-83ddf6924568                    62.0            29
#
#                                       tumour_grade  first_therapy_type  ...  \
# Unnamed: 0                                                              ...
# 003819bc-c415-4e76-887c-931d60ed39e7             0                   0  ...
# 0040b1b6-b07a-4b6e-90ef-133523eaf412            21                   4  ...
# 00493087-9d9d-40ca-86d5-936f1b951c93            37                   0  ...
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa             3                   0  ...
# 005794f1-5a87-45b5-9811-83ddf6924568             0                   0  ...
#
#                                          SBS86     SBS87     SBS88     SBS89  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7  0.000018  0.043297  0.002587  0.000110
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.001064  0.000472  0.006128  0.014017
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.007644  0.066593  0.003875  0.008409
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.006881  0.014572  0.005315  0.034945
# 005794f1-5a87-45b5-9811-83ddf6924568  0.002754  0.006760  0.008834  0.040637
#
#                                          SBS90     SBS91     SBS92     SBS93  \
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7  0.001679  0.000330  0.008414  0.012260
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.003671  0.002160  0.015290  0.010472
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.001092  0.004163  0.013443  0.012461
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.000375  0.024285  0.001300  0.002455
# 005794f1-5a87-45b5-9811-83ddf6924568  0.002801  0.003005  0.011455  0.008315
#
#                                          SBS94  Number of NaN's
# Unnamed: 0
# 003819bc-c415-4e76-887c-931d60ed39e7  0.010864               23
# 0040b1b6-b07a-4b6e-90ef-133523eaf412  0.012708               23
# 00493087-9d9d-40ca-86d5-936f1b951c93  0.046001               29
# 00508f2b-36bf-44fc-b66b-97e1f3e40bfa  0.023321               25
# 005794f1-5a87-45b5-9811-83ddf6924568  0.079724               26
#
# [5 rows x 120 columns]

# %%
df_dummies[TARGET] = encoders_dict[TARGET].transform(df_dummies[TARGET])

# %% [markdown]
# ### Modeling

# %%
from sklearn.decomposition import PCA
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_validate, GridSearchCV
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score, accuracy_score, make_scorer

RANDOM_STATE = 100
MODELS = [
    GradientBoostingClassifier, RandomForestClassifier, LogisticRegression,
    KNeighborsClassifier, SVC, LinearSVC, LGBMClassifier, XGBClassifier
]
cv = StratifiedKFold(n_splits = 5, shuffle = True, random_state = RANDOM_STATE)
scorers = {
  'roc_auc': make_scorer(roc_auc_score),
  'accuracy': make_scorer(accuracy_score),
  'f1': make_scorer(f1_score),
  'precision': make_scorer(precision_score),
  'recall': make_scorer(recall_score),
}

# %%
X, y = df_dummies.drop(TARGET, axis=1), df_dummies[TARGET]
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle = True, stratify = y)
X_train.shape, X_test.shape
# Out:
# ((4622, 745), (1541, 745))

# %%
reducer = PCA(n_components = 1)
X_truncated = reducer.fit_transform(X_test)
X_truncated = X_truncated.reshape(1, -1)[0]
reducer.explained_variance_ratio_.sum()
# Out:
# 0.9999425548902304

# %%
def model_metrics(y_true, y_predicted):
    print(f"Accuracy : {accuracy_score(y_true, y_predicted)}")
    print(f"Precision : {precision_score(y_true, y_predicted)}")
    print(f"Recall : {recall_score(y_true, y_predicted)}")
    print(f"F1 Score : {f1_score(y_true, y_predicted)}")
    print(f"AUC Score : {roc_auc_score(y_true, y_predicted)}")

def scatter_predicted_vs_true(x, y_true, y_predicted):
    fig, ax = plt.subplots()
    ax.scatter(x, y_true, c='green')
    ax.scatter(x, y_predicted, c='red')
    plt.show()

def cv_model(model_type, model_name, X_train, y_train, **kwargs):
    model = model_type(**kwargs)
    cv_results = cross_validate(model, X_train, y_train, scoring = scorers, cv = cv)
    print(f"Model - {model_name}, Results - {cv_results['test_roc_auc']}, Mean - {cv_results['test_roc_auc'].mean()}")
    score = cv_results['test_roc_auc'].mean()
    if np.isnan(score):
        score = 0
    return score

# %%
def fit_cv(X_train, y_train):
    scores = dict()
    model_names = [str(model_cls.__name__) for model_cls in MODELS]

    for model_cls in MODELS:
        model_name = str(model_cls.__name__)
        scores[model_name] = cv_model(model_cls, model_name, X_train, y_train)
    scores = dict(sorted(scores.items(), key=lambda item: item[1]))

    best_model_name = None
    for i, model_name in enumerate(scores):
        print(f"{i + 1}. {model_name} - {scores[model_name]}")
        best_model_name = model_name
    best_model_cls = MODELS[model_names.index(best_model_name)]
    
    return best_model_cls

best_model = fit_cv(X_train, y_train)
best_model

# %%
grid = {
    'n_estimators': list(range(60, 221, 40)) + [500, 1000], 
    'learning_rate': [0.05, 0.1, 0.3], 
    'reg_alpha': [0, 0.5, 2],
    'reg_lambda': [0, 0.5, 2],
    'colsample_bytree': [0.4, 0.6, 0.8, 1], 
    'subsample': [0.6, 0.8, 1]
}
fit_kwargs = {"eval_metric" : "auc", "eval_set": [(X_train, y_train), (X_test, y_test)], "early_stopping_rounds": 20}
cv_estimator = GridSearchCV(best_model(), grid, cv = cv, scoring = scorers['roc_auc'])
cv_estimator.fit(X_train, y_train, **fit_kwargs)
cv_estimator.score(X_test, y_test)

# %%
cv_estimator.best_params_

# %%
y_pred = cv_estimator.predict(X_test)
model_metrics(y_test, y_pred)
scatter_predicted_vs_true(X_truncated, y_test, y_pred)

# %% [markdown]
# Final model

# %%
best_params = {
    'colsample_bytree': 0.4,
    'learning_rate': 0.05,
    'n_estimators': 60,
    'reg_alpha': 0,
    'reg_lambda': 0,
    'subsample': 0.6
}
fit_kwargs = {
    "eval_metric" : "auc", 
    "eval_set": [(X_train, y_train), (X_test, y_test)], 
    "early_stopping_rounds": 20
}
model = LGBMClassifier(**best_params)
model.fit(X_train, y_train, **fit_kwargs)
model.score(X_test, y_test)

# %% [markdown]
# Feature importances

# %%
feature_imp = sorted([(imp, col) for imp, col in zip(model.feature_importances_, X.columns) if imp > 0])
feature_imp = pd.DataFrame(feature_imp, columns=['Value','Feature'])
plt.figure(figsize=(28, 30))
sns.barplot(x = "Value", y = "Feature", data = feature_imp.sort_values(by = "Value", ascending = False))
plt.tight_layout()
plt.show()
